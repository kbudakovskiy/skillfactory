# %% [markdown]
# <center> <img src = https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/hh%20label.jpg alt="drawing" style="width:400px;">

# %% [markdown]
# # <center> Проект: Анализ резюме из HeadHunter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Исследование структуры данных

# %% [markdown]
# 1. Прочитайте данные с помощью библиотеки Pandas. Совет: перед чтением обратите внимание на разделитель внутри файла.

# %% [markdown]
# 2. Выведите несколько первых (последних) строк таблицы, чтобы убедиться в том, что ваши данные не повреждены. Ознакомьтесь с признаками и их структурой.

# %%
data = pd.read_csv('data/dst-3.0_16_1_hh_database.csv', delimiter=';')

# %%
data.head()
# Out:
#                                    Пол, возраст           ЗП  \
# 0    Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1     Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2  Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3      Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4     Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
#
#                            Ищет работу на должность:  \
# 0                            Системный администратор
# 1                               Технический писатель
# 2                                           Оператор
# 3  Веб-разработчик (HTML / CSS / JS / PHP / базы ...
# 4                  Региональный менеджер по продажам
#
#                         Город, переезд, командировки  \
# 0  Советск (Калининградская область) , не готов к...
# 1  Королев , не готов к переезду , готов к редким...
# 2  Тверь , не готова к переезду , не готова к ком...
# 3  Саратов , не готов к переезду , готов к редким...
# ...

# %%
data.tail()
# Out:
#                                        Пол, возраст           ЗП  \
# 44739    Мужчина ,  30 лет , родился 17 января 1989   50000 руб.
# 44740      Мужчина ,  27 лет , родился 5 марта 1992   39000 руб.
# 44741  Женщина ,  48 лет , родилась 26 декабря 1970   40000 руб.
# 44742   Мужчина ,  24 года , родился 6 октября 1994   20000 руб.
# 44743    Мужчина ,  38 лет , родился 25 апреля 1980  120000 руб.
#
#                                Ищет работу на должность:  \
# 44739  Финансист, аналитик, экономист, бухгалтер, мен...
# 44740             Системный администратор, IT-специалист
# 44741                         Аналитик данных, Математик
# 44742                                   Контент-менеджер
# 44743                               Руководитель проекта
#
#                             Город, переезд, командировки  \
# 44739  Тверь , готов к переезду (Москва, Химки) , гот...
# 44740  Липецк , готов к переезду , готов к командировкам
# ...

# %% [markdown]
# 3. Выведите основную информацию о числе непустых значений в столбцах и их типах в таблице.

# %%
data.shape
# Out:
# (44744, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Пол, возраст                     44744 non-null  object
#  1   ЗП                               44744 non-null  object
#  2   Ищет работу на должность:        44744 non-null  object
#  3   Город, переезд, командировки     44744 non-null  object
#  4   Занятость                        44744 non-null  object
#  5   График                           44744 non-null  object
#  6   Опыт работы                      44576 non-null  object
#  7   Последнее/нынешнее место работы  44743 non-null  object
#  8   Последняя/нынешняя должность     44742 non-null  object
#  9   Образование и ВУЗ                44744 non-null  object
#  10  Обновление резюме                44744 non-null  object
#  11  Авто                             44744 non-null  object
# ...

# %% [markdown]
# 4. Обратите внимание на информацию о числе непустых значений.

# %%
data.count().sort_values()
# Out:
# Опыт работы                        44576
# Последняя/нынешняя должность       44742
# Последнее/нынешнее место работы    44743
# Пол, возраст                       44744
# Город, переезд, командировки       44744
# Ищет работу на должность:          44744
# График                             44744
# ЗП                                 44744
# Занятость                          44744
# Образование и ВУЗ                  44744
# Обновление резюме                  44744
# Авто                               44744
# dtype: int64

# %% [markdown]
# 5. Выведите основную статистическую информацию о столбцах.

# %%
data.describe()
# Out:
#                                          Пол, возраст          ЗП  \
# count                                           44744       44744
# unique                                          16003         690
# top     Мужчина ,  32 года , родился 17 сентября 1986  50000 руб.
# freq                                               18        4064
#
#        Ищет работу на должность:  \
# count                      44744
# unique                     14929
# top      Системный администратор
# freq                        3099
#
#                              Город, переезд, командировки         Занятость  \
# count                                               44744             44744
# unique                                              10063                38
# top     Москва , не готов к переезду , не готов к кома...  полная занятость
# freq                                                 1261             30026
#
#              График                                        Опыт работы  \
# ...

# %% [markdown]
# # Преобразование данных

# %% [markdown]
# 1. Начнем с простого - с признака **"Образование и ВУЗ"**. Его текущий формат это: **<Уровень образования год выпуска ВУЗ специальность...>**. Например:
# * Высшее образование 2016 Московский авиационный институт (национальный исследовательский университет)...
# * Неоконченное высшее образование 2000  Балтийская государственная академия рыбопромыслового флота…
# Нас будет интересовать только уровень образования.
#
# Создайте с помощью функции-преобразования новый признак **"Образование"**, который должен иметь 4 категории: "высшее", "неоконченное высшее", "среднее специальное" и "среднее".
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак "Образование и ВУЗ".
#
# Совет: обратите внимание на структуру текста в столбце **"Образование и ВУЗ"**. Гарантируется, что текущий уровень образования соискателя всегда находится в первых 2ух слов и начинается с заглавной буквы. Воспользуйтесь этим.
#
# *Совет: проверяйте полученные категории, например, с помощью метода unique()*

# %%
df = data.copy()

# %%
# Извлекаем уровень образования с помощью regexp
import re
df['Образование'] = df['Образование и ВУЗ'].apply(lambda text: re.search(r'^(.*?)\s*\d{4}', text).group(1).split(' образование')[0].lower())
df['Образование'].value_counts()
# Out:
# Образование
# высшее                 33863
# среднее специальное     5765
# неоконченное высшее     4557
# среднее                  559
# Name: count, dtype: int64

# %%
df.drop(columns='Образование и ВУЗ')
# Out:
#                                        Пол, возраст           ЗП  \
# 0        Мужчина ,  39 лет , родился 27 ноября 1979   29000 руб.
# 1         Мужчина ,  60 лет , родился 20 марта 1959   40000 руб.
# 2      Женщина ,  36 лет , родилась 12 августа 1982   20000 руб.
# 3          Мужчина ,  38 лет , родился 25 июня 1980  100000 руб.
# 4         Женщина ,  26 лет , родилась 3 марта 1993  140000 руб.
# ...                                             ...          ...
# 44739    Мужчина ,  30 лет , родился 17 января 1989   50000 руб.
# 44740      Мужчина ,  27 лет , родился 5 марта 1992   39000 руб.
# 44741  Женщина ,  48 лет , родилась 26 декабря 1970   40000 руб.
# 44742   Мужчина ,  24 года , родился 6 октября 1994   20000 руб.
# 44743    Мужчина ,  38 лет , родился 25 апреля 1980  120000 руб.
#
#                                Ищет работу на должность:  \
# 0                                Системный администратор
# 1                                   Технический писатель
# ...

# %% [markdown]
# 2. Теперь нас интересует столбец **"Пол, возраст"**. Сейчас он представлен в формате **<Пол , возраст , дата рождения >**. Например:
# * Мужчина , 39 лет , родился 27 ноября 1979
# * Женщина , 21 год , родилась 13 января 2000
# Как вы понимаете, нам необходимо выделить каждый параметр в отдельный столбец.
#
# Создайте два новых признака **"Пол"** и **"Возраст"**. При этом важно учесть:
# * Признак пола должен иметь 2 уникальных строковых значения: 'М' - мужчина, 'Ж' - женщина.
# * Признак возраста должен быть представлен целыми числами.
#
# Выполните преобразование, ответьте на контрольные вопросы и удалите признак **"Пол, возраст"** из таблицы.
#
# *Совет: обратите внимание на структуру текста в столбце, в части на то, как разделены параметры пола, возраста и даты рождения между собой - символом ' , '.
# Гарантируется, что структура одинакова для всех строк в таблице. Вы можете воспользоваться этим.*

# %%
df['Пол'] = df['Пол, возраст'].apply(lambda text: 'М' if text.split(sep=',')[0] == 'Мужчина ' else 'Ж')
display(df['Пол'].count())
display(df['Пол'].value_counts())
# Out:
# np.int64(44744)
# Пол
# М    36211
# Ж     8533
# Name: count, dtype: int64

# %% [markdown]
# Сколько процентов женских резюме представлено в наших данных? Ответ округлите до сотых.

# %%
round(df['Пол'].value_counts().get('Ж', 0) / df['Пол'].count() * 100, 2)
# Out:
# np.float64(19.07)

# %%
df['Возраст'] = df['Пол, возраст'].apply(lambda text: int(text.split(sep=',')[1].split()[0]))

# %% [markdown]
# Чему равен средний возраст соискателей? Ответ округлите до десятых.

# %%
round(df['Возраст'].mean(), 1)
# Out:
# np.float64(32.2)

# %%
df = df.drop(columns='Пол, возраст')

# %% [markdown]
# 3. Следующим этапом преобразуем признак **"Опыт работы"**. Его текущий формат - это: **<Опыт работы: n лет m месяцев, периоды работы в различных компаниях…>**.
#
# Из столбца нам необходимо выделить общий опыт работы соискателя в месяцах, новый признак назовем "Опыт работы (месяц)"
#
# Для начала обсудим условия решения задачи:
# * Во-первых, в данном признаке есть пропуски. Условимся, что если мы встречаем пропуск, оставляем его как есть (функция-преобразование возвращает NaN)
# * Во-вторых, в данном признаке есть скрытые пропуски. Для некоторых соискателей в столбце стоит значения "Не указано". Их тоже обозначим как NaN (функция-преобразование возвращает NaN)
# * В-третьих, нас не интересует информация, которая описывается после указания опыта работы (периоды работы в различных компаниях)
# * В-четвертых, у нас есть проблема: опыт работы может быть представлен только в годах или только месяцах. Например, можно встретить следующие варианты:
#     * Опыт работы 3 года 2 месяца…
#     * Опыт работы 4 года…
#     * Опыт работы 11 месяцев…
#     * Учитывайте эту особенность в вашем коде
#
# Учитывайте эту особенность в вашем коде
#
# В результате преобразования у вас должен получиться столбец, содержащий информацию о том, сколько месяцев проработал соискатель.
# Выполните преобразование, ответьте на контрольные вопросы и удалите столбец **"Опыт работы"** из таблицы.

# %% [markdown]
# Заменим "Не указано на NaN

# %%
display(df[df['Опыт работы'] == 'Не указано']['Опыт работы'].count())
df['Опыт работы'] = df['Опыт работы'].replace('Не указано', np.nan)
# Out:
# np.int64(2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ЗП                               44744 non-null  object
#  1   Ищет работу на должность:        44744 non-null  object
#  2   Город, переезд, командировки     44744 non-null  object
#  3   Занятость                        44744 non-null  object
#  4   График                           44744 non-null  object
#  5   Опыт работы                      44574 non-null  object
#  6   Последнее/нынешнее место работы  44743 non-null  object
#  7   Последняя/нынешняя должность     44742 non-null  object
#  8   Образование и ВУЗ                44744 non-null  object
#  9   Обновление резюме                44744 non-null  object
#  10  Авто                             44744 non-null  object
#  11  Образование                      44744 non-null  object
# ...

# %%
# Функция отвечает за преобразование строков данных об опыте работы в int в месяцах
def convert_to_months(exp):
    """
    Преобразует строковое представление опыта работы в общее количество месяцев.

    Аргументы:
        exp (str): Строка с опытом работы (например, "5 лет 3 месяца").

    Возвращает:
        int: Общее количество месяцев. Если входное значение NaN, возвращает его без изменений.
    """
    if pd.notna(exp):
        # Откидываем лишний мусор из строки
        exp = str(exp).split(sep='  ')[0].replace('Опыт работы ', '')

        # Регулярное выражение для извлечения лет и месяцев
        pattern = r'(?:(\d+)\s*(?:лет|года|год))?\s*(?:(\d+)\s*(?:месяцев|месяца|месяц))?'
        match = re.match(pattern, exp)
        
        if not match:
            return 0
        
        # Подсчет лет и месяцев
        years = int(match.group(1)) if match.group(1) else 0
        months = int(match.group(2)) if match.group(2) else 0
        
        # Вычисление общего количества месяцев
        total_months = years * 12 + months
        return int(total_months)
    else:
        return exp

# %%
df['Опыт работы (месяц)']  = df['Опыт работы'].apply(convert_to_months)

# %% [markdown]
# Чему равен медианный опыт работы (в месяцах) в нашей таблице?

# %%
df['Опыт работы (месяц)'].median()
# Out:
# np.float64(100.0)

# %%
df = df.drop(columns='Опыт работы')

# %% [markdown]
# 4. Хорошо идем! Следующий на очереди признак "Город, переезд, командировки". Информация в нем представлена в следующем виде: **<Город , (метро) , готовность к переезду (города для переезда) , готовность к командировкам>**. В скобках указаны необязательные параметры строки. Например, можно встретить следующие варианты:
#
# * Москва , не готов к переезду , готов к командировкам
# * Москва , м. Беломорская , не готов к переезду, не готов к командировкам
# * Воронеж , готов к переезду (Сочи, Москва, Санкт-Петербург) , готов к командировкам
#
# Создадим отдельные признаки **"Город"**, **"Готовность к переезду"**, **"Готовность к командировкам"**. При этом важно учесть:
#
# * Признак **"Город"** должен содержать только 4 категории: "Москва", "Санкт-Петербург" и "город-миллионник" (их список ниже), остальные обозначьте как "другие".
#
#     Список городов-миллионников:
#
#    <code>million_cities = ['Новосибирск', 'Екатеринбург','Нижний Новгород','Казань', 'Челябинск','Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж','Волгоград']
#     </code>
#     Инфорация о метро, рядом с которым проживает соискатель нас не интересует.
# * Признак **"Готовность к переезду"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к переезду в признаке "Город, переезд, командировки". Например:
#     * … , готов к переезду , …
#     * … , не готова к переезду , …
#     * … , готова к переезду (Москва, Санкт-Петербург, Ростов-на-Дону)
#     * … , хочу переехать (США) , …
#
#     Нас интересует только сам факт возможности или желания переезда.
# * Признак **"Готовность к командировкам"** должен иметь два возможных варианта: True или False. Обратите внимание, что возможны несколько вариантов описания готовности к командировкам в признаке "Город, переезд, командировки". Например:
#     * … , готов к командировкам , …
#     * … , готова к редким командировкам , …
#     * … , не готов к командировкам , …
#
#     Нас интересует только сам факт готовности к командировке.
#
#     Еще один важный факт: при выгрузки данных у некоторых соискателей "потерялась" информация о готовности к командировкам. Давайте по умолчанию будем считать, что такие соискатели не готовы к командировкам.
#
# Выполните преобразования и удалите столбец **"Город, переезд, командировки"** из таблицы.
#
# *Совет: обратите внимание на то, что структура текста может меняться в зависимости от указания ближайшего метро. Учите это, если будете использовать порядок слов в своей программе.*

# %%
million_cities = ['Новосибирск', 'Екатеринбург', 'Нижний Новгород', 'Казань', 'Челябинск', 'Омск', 'Самара', 'Ростов-на-Дону', 'Уфа', 'Красноярск', 'Пермь', 'Воронеж', 'Волгоград' ]
def get_city(text):
    """
    Определяет категорию города на основе текста.

    Аргументы:
        text (str): Текст, содержащий название города.

    Возвращает:
        str: Категория города ('Москва', 'Санкт-Петербург', 'город-миллионник', 'другие').
    """
    city = text.split(' , ')[0]
    if city in ['Москва', 'Санкт-Петербург']:
        return city
    elif city in million_cities:
        return 'город-миллионник'
    else:
        return 'другие'
    
def get_ready_to_relocate(text):
    """
    Определяет, готов ли человек к переезду, на основе текста.

    Аргументы:
        text (str): Текст, содержащий информацию о готовности к переезду.

    Возвращает:
        bool: True, если готов к переезду, иначе False.
    """
    pattern = r"(готов|не готов|готова|не готова| хочу | мечтаю)\s*к?\s*перее[а-я]*"
    matches = re.findall(pattern, text)[0]
    if 'не' in matches:
        return False
    else:
        return True

def get_ready_to_business_trip(text):
    """
    Определяет, готов ли человек к командировкам, на основе текста.

    Аргументы:
        text (str): Текст, содержащий информацию о готовности к командировкам.

    Возвращает:
        bool: True, если готов к командировкам, иначе False.
    """
    pattern = r"(готов|не готов|готова|не готова)\s*к?\s*(редким )?\s*команд[а-я]*"
    try:
        matches = re.findall(pattern, text)[0]
        if 'не' in matches[0]:
            return False
        else:
            return True
    except IndexError:
        return False

# %%
# Извлекаем необходимые признаки с подготовленными функциями
df['Город'] = df['Город, переезд, командировки'].apply(get_city)
df['Готовность к переезду'] = df['Город, переезд, командировки'].apply(get_ready_to_relocate)
df['Готовность к командировкам'] = df['Город, переезд, командировки'].apply(get_ready_to_business_trip)

# %% [markdown]
# Сколько процентов соискателей живут в Санкт-Петербурге? Ответ округлите до целого.

# %%
round(df[df['Город'] == 'Санкт-Петербург'].shape[0] / df.shape[0] * 100, 0)
# Out:
# 11.0

# %% [markdown]
# Сколько процентов соискателей готовы одновременно и к переездам, и к командировкам? Ответ округлите до целого.

# %%
round(df[(df['Готовность к переезду'] == True) & (df['Готовность к командировкам'] == True)].shape[0] / df.shape[0] * 100, 0)
# Out:
# 32.0

# %%
df = df.drop(columns='Город, переезд, командировки')

# %% [markdown]
# 5. Рассмотрим поближе признаки **"Занятость"** и **"График"**. Сейчас признаки представляют собой набор категорий желаемой занятости (полная занятость, частичная занятость, проектная работа, волонтерство, стажировка) и желаемого графика работы (полный день, сменный график, гибкий график, удаленная работа, вахтовый метод).
# На сайте hh.ru соискатель может указывать различные комбинации данных категорий, например:
# * полная занятость, частичная занятость
# * частичная занятость, проектная работа, волонтерство
# * полный день, удаленная работа
# * вахтовый метод, гибкий график, удаленная работа, полная занятость
#
# Такой вариант признаков имеет множество различных комбинаций, а значит множество уникальных значений, что мешает анализу. Нужно это исправить!
#
# Давайте создадим признаки-мигалки для каждой категории: если категория присутствует в списке желаемых соискателем, то в столбце на месте строки рассматриваемого соискателя ставится True, иначе - False.
#
# Такой метод преобразования категориальных признаков называется One Hot Encoding и его схема представлена на рисунке ниже:
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/ohe.jpg>
#
# Выполните данное преобразование для признаков "Занятость" и "График", ответьте на контрольные вопросы, после чего удалите их из таблицы

# %%
employments = ['полная занятость', 'частичная занятость', 'проектная работа', 'стажировка', 'волонтерство']
charts = ['полный день', 'сменный график', 'гибкий график', 'удалённая работа', 'вахтовый метод']

# Создаем признаки по схеме One Hot Encoding для колонки "Занятость"
for item in employments:
    df[item.capitalize()] = df['Занятость'].apply(lambda text: True if item in text else False)

# Создаем признаки по схеме One Hot Encoding для колонки "График"
for item in charts:
    df[item.capitalize()] = df['График'].apply(lambda text: True if item in text else False)

# %% [markdown]
# Сколько людей ищут проектную работу и волонтерство (в обоих столбцах стоит True)?

# %%
df[(df['Проектная работа'] == True) & (df['Волонтерство'] == True)].shape[0]
# Out:
# 436

# %% [markdown]
# Сколько людей хотят работать вахтовым методом и с гибким графиком (в обоих столбцах стоит True)?

# %%
df[(df['Вахтовый метод'] == True) & (df['Гибкий график'] == True)].shape[0]
# Out:
# 2311

# %% [markdown]
# 6. (2 балла) Наконец, мы добрались до самого главного и самого важного - признака заработной платы **"ЗП"**.
# В чем наша беда? В том, что помимо желаемой заработной платы соискатель указывает валюту, в которой он бы хотел ее получать, например:
# * 30000 руб.
# * 50000 грн.
# * 550 USD
#
# Нам бы хотелось видеть заработную плату в единой валюте, например, в рублях. Возникает вопрос, а где взять курс валют по отношению к рублю?
#
# На самом деле язык Python имеет в арсенале огромное количество возможностей получения данной информации, от обращения к API Центробанка, до использования специальных библиотек, например pycbrf. Однако, это не тема нашего проекта.
#
# Поэтому мы пойдем в лоб: обратимся к специальным интернет-ресурсам для получения данных о курсе в виде текстовых файлов. Например, MDF.RU, данный ресурс позволяет удобно экспортировать данные о курсах различных валют и акций за указанные периоды в виде csv файлов. Мы уже сделали выгрузку курсов валют, которые встречаются в наших данных за период с 29.12.2017 по 05.12.2019. Скачать ее вы можете **на платформе**
#
# Создайте новый DataFrame из полученного файла. В полученной таблице нас будут интересовать столбцы:
# * "currency" - наименование валюты в ISO кодировке,
# * "date" - дата,
# * "proportion" - пропорция,
# * "close" - цена закрытия (последний зафиксированный курс валюты на указанный день).
#
#
# Перед вами таблица соответствия наименований иностранных валют в наших данных и их общепринятых сокращений, которые представлены в нашем файле с курсами валют. Пропорция - это число, за сколько единиц валюты указан курс в таблице с курсами. Например, для казахстанского тенге курс на 20.08.2019 составляет 17.197 руб. за 100 тенге, тогда итоговый курс равен - 17.197 / 100 = 0.17197 руб за 1 тенге.
# Воспользуйтесь этой информацией в ваших преобразованиях.
#
# <img src=https://raw.githubusercontent.com/AndreyRysistov/DatasetsForPandas/main/table.jpg>
#
#
# Осталось только понять, откуда брать дату, по которой определяется курс? А вот же она - в признаке **"Обновление резюме"**, в нем содержится дата и время, когда соискатель выложил текущий вариант своего резюме. Нас интересует только дата, по ней бы и будем сопоставлять курсы валют.
#
# Теперь у нас есть вся необходимая информация для того, чтобы создать признак "ЗП (руб)" - заработная плата в рублях.
#
# После ответа на контрольные вопросы удалите исходный столбец заработной платы "ЗП" и все промежуточные столбцы, если вы их создавали.

# %% [markdown]
# Итак, давайте обсудим возможный алгоритм преобразования:
# 1. Перевести признак "Обновление резюме" из таблицы с резюме в формат datetime и достать из него дату. В тот же формат привести признак "date" из таблицы с валютами.
# 2. Выделить из столбца "ЗП" сумму желаемой заработной платы и наименование валюты, в которой она исчисляется. Наименование валюты перевести в стандарт ISO согласно с таблицей выше.
# 3. Присоединить к таблице с резюме таблицу с курсами по столбцам с датой и названием валюты (подумайте, какой тип объединения надо выбрать, чтобы в таблице с резюме сохранились данные о заработной плате, изначально представленной в рублях). Значение close для рубля заполнить единицей 1 (курс рубля самого к себе)
# 4. Умножить сумму желаемой заработной платы на присоединенный курс валюты (close) и разделить на пропорцию (обратите внимание на пропуски после объединения в этих столбцах), результат занести в новый столбец "ЗП (руб)".

# %%
df['Обновление резюме'] = pd.to_datetime(df['Обновление резюме'], dayfirst=True).dt.date

# %%
exchange_df = pd.read_csv('data/ExchangeRates.csv')
exchange_df = exchange_df[['currency', 'close', 'date', 'proportion']]
exchange_df['date'] = pd.to_datetime(exchange_df['date'], format='%d/%m/%y').dt.date

exchange_df[pd.to_datetime(exchange_df['date'], format='%d/%m/%y') == '2019-04-22']
# Out:
#      currency    close        date  proportion
# 479       USD  63.9602  2019-04-22           1
# 1187      EUR  71.9232  2019-04-22           1
# 1895      KZT  16.8680  2019-04-22         100
# 2603      KGS  91.6040  2019-04-22          10
# 3311      BYN  30.5314  2019-04-22           1
# 4019      UAH  23.8468  2019-04-22          10
# 4727      UZS  75.6447  2019-04-22       10000
# 5435      AZN  37.7013  2019-04-22           1

# %%
# Уберем точки присутсвующие в сокращении именования валют
df['Валюта'] = df['ЗП'].apply(lambda text: str(text.split()[1]).replace('.', ''))

# Приведем все валюты к стандарту ISO и выделим их в отдельную колонку с названием 'Валюта'
iso_dic = {
    'белруб': 'BYN',
    'грн': 'UAH',
    'сум': 'UZS',
    'руб': 'RUB'
}

for key, value in iso_dic.items():
    df['Валюта'] = df['Валюта'].apply(lambda text: text.replace(key, value))

# Остаим в колонки ЗП числовые значения ЗП
df['ЗП'] = df['ЗП'].apply(lambda text: int(text.split()[0]))
display(df['Валюта'].value_counts())
# Out:
# Валюта
# RUB    42471
# KZT     1108
# USD      628
# BYN      329
# EUR      106
# UAH       73
# UZS       20
# KGS        6
# AZN        3
# Name: count, dtype: int64

# %%
# Объединим таблицы установив курс конвертации валют
merged_df  = pd.merge(  df, 
                        exchange_df,
                        left_on=['Обновление резюме', 'Валюта'],
                        right_on=['date', 'currency'],
                        how='left')
# Удалим ненужные колонки
merged_df.drop(columns=['currency', 'date'], inplace=True)

# Для рубля установим кур конвертации 1
merged_df['proportion'] = merged_df['proportion'].replace(np.nan, 1)
merged_df['close'] = merged_df['close'].replace(np.nan, 1)

# Приведем все зарплаты к единому курсу в рублях
merged_df['Зарплата в рублях'] = merged_df['close'] / merged_df['proportion'] * merged_df['ЗП']
df = merged_df.drop(columns=['close', 'proportion', 'ЗП'])

# Подсчитаем медиану заработных плат
display(df['Зарплата в рублях'].median())
# Out:
# np.float64(59019.0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44744 entries, 0 to 44743
# Data columns (total 27 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ищет работу на должность:        44744 non-null  object
#  1   Занятость                        44744 non-null  object
#  2   График                           44744 non-null  object
#  3   Последнее/нынешнее место работы  44743 non-null  object
#  4   Последняя/нынешняя должность     44742 non-null  object
#  5   Образование и ВУЗ                44744 non-null  object
#  6   Обновление резюме                44744 non-null  object
#  7   Авто                             44744 non-null  object
#  8   Образование                      44744 non-null  object
#  9   Пол                              44744 non-null  object
#  10  Возраст                          44744 non-null  int64
#  11  Опыт работы (месяц)              44574 non-null  float64
# ...

# %% [markdown]
# # Исследование зависимостей в данных

# %% [markdown]
# 1. Постройте распределение признака **"Возраст"**. Опишите распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится возраст большинства соискателей? Есть ли аномалии для признака возраста, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Создаем фигуру с двумя подграфиками
plt.figure(figsize=(16, 6))

# Гистограмма с кривой плотности (KDE)
plt.subplot(1, 2, 1)
sns.histplot(df['Возраст'], bins=40, kde=True, color='blue')
plt.title('Гистограмма возраста')
plt.xlabel('Возраст')
plt.ylabel('Частота')

# Коробчатая диаграмма (boxplot)
plt.subplot(1, 2, 2)
sns.boxplot(x=df['Возраст'], color='orange')
plt.title('Коробчатая диаграмма возраста')
plt.xlabel('Возраст')

plt.tight_layout()
plt.show()

# Описательная статистика
mode_age = df['Возраст'].mode()[0]
min_age = df['Возраст'].min()
max_age = df['Возраст'].max()
median_age = df['Возраст'].median()

print(f"Мода: Возраст: {mode_age}")
print(f"Медиана: Возраст: {median_age}")
print(f"Минимальный возраст: {min_age}")
print(f"Максимальный возраст: {max_age}")
# Out:
# Мода: Возраст: 30
# Медиана: Возраст: 31.0
# Минимальный возраст: 14
# Максимальный возраст: 100

# %% [markdown]
# Выводы
#
# * Мода распределения равнв 30 годам, Минимальный возраст 14 лет, максимальный возраст 100 лет, медиана равна 31 году.
# * Возраст большинства соискателей находится от 25 до 40 лет. На графике присутствют аномалиии, явно выраженная аномалия - это соискатель в возрасте 100 лет, но также можно к аномалиям можно отнести соискателей в возрасте старше 70 лет.
# * 25 лет возраст, когда большинство соискателей выходит на рынок труда поэтому количество активных резюме резко возрастает
# * После 30 лет количество соискателей начинает сокращаться, скорее всего это связано с тем что с возрастом люди реже меняют работу

# %% [markdown]
# 2. Постройте распределение признака **"Опыт работы (месяц)"**. Опишите данное распределение, отвечая на следующие вопросы: чему равна мода распределения, каковы предельные значения признака, в каком примерном интервале находится опыт работы большинства соискателей? Есть ли аномалии для признака опыта работы, какие значения вы бы причислили к их числу?
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Создаем фигуру с двумя подграфиками
plt.figure(figsize=(16, 6))

# Гистограмма с кривой плотности (KDE)
plt.subplot(1, 2, 1)
sns.histplot(df['Опыт работы (месяц)'], bins=40, kde=True, color='blue')
plt.title('Гистограмма Опыт работы (месяц)')
plt.xlabel('Месяц')
plt.ylabel('Частота')

# Коробчатая диаграмма (boxplot)
plt.subplot(1, 2, 2)
sns.boxplot(x=df['Опыт работы (месяц)'], color='orange')
plt.title('Опыт работы (месяц)')
plt.xlabel('Месяц')

plt.tight_layout()
plt.show()

# Описательная статистика
mode_exp = df['Опыт работы (месяц)'].mode()[0]
min_exp = df['Опыт работы (месяц)'].min()
max_exp = df['Опыт работы (месяц)'].max()
median_exp = df['Опыт работы (месяц)'].median()

print(f"Мода Опыт работы (месяц): {mode_exp}")
print(f"Минимальный опыт работы: {min_exp}")
print(f"Максимальный опыт работы: {max_exp}")
print(f"Медиана Опыт работы (месяц): {median_exp}")
# Out:
# Мода Опыт работы (месяц): 81.0
# Минимальный опыт работы: 1.0
# Максимальный опыт работы: 1188.0
# Медиана Опыт работы (месяц): 100.0

# %% [markdown]
# Выводы
#
# * Мода распределения равна 81 месяцу, минимальный опыт работы равен одному месяцу максимальный опыт работы равен 1188 месяцам. Опыт работы большинства соискателей находится в пределах до 250 месяцев. Аномалии присутствует к ним можно отнести все что больше 480 месяцевстажа работы.

# %% [markdown]
# 3. Постройте распределение признака **"ЗП (руб)"**. Опишите данное распределение, отвечая на следующие вопросы: каковы предельные значения признака, в каком примерном интервале находится заработная плата большинства соискателей? Есть ли аномалии для признака заработных плат? Обратите внимание на гигантские размеры желаемой заработной платы.
# *Совет: постройте гистограмму и коробчатую диаграмму рядом.*

# %%
# Отсечем очевидные выбрасы по уровню заработной платы 
barplot_df = df[df['Зарплата в рублях'] < 700000]

# Создаем фигуру с двумя подграфиками
plt.figure(figsize=(16, 6))

# Гистограмма с кривой плотности (KDE)
plt.subplot(1, 2, 1)
sns.histplot(barplot_df['Зарплата в рублях'], bins=40, kde=True, color='blue')
plt.title('Гистограмма Зарплата в рублях')
plt.xlabel('Заработная плата, руб')
plt.ylabel('Частота')

# Коробчатая диаграмма (boxplot)
plt.subplot(1, 2, 2)
sns.boxplot(x=barplot_df['Зарплата в рублях'], color='orange')
plt.title('Зарплата в рублях')
plt.xlabel('Заработная плата, руб')

plt.tight_layout()
plt.show()

# Описательная статистика
mode_salary = df['Зарплата в рублях'].mode()[0]
min_salary = df['Зарплата в рублях'].min()
max_salary = df['Зарплата в рублях'].max()
median_salary = df['Зарплата в рублях'].median()

print(f"Мода: Зарплата в рублях: {mode_salary}")
print(f"Минимальная заработная плата: {min_salary}")
print(f"Максимальный заработная плата: {max_salary}")
print(f"Медиана: Зарплата в рублях: {median_salary}")
# Out:
# Мода: Зарплата в рублях: 50000.0
# Минимальная заработная плата: 1.0
# Максимальный заработная плата: 24304876.0
# Медиана: Зарплата в рублях: 59019.0

# %% [markdown]
# Выводы
#
# * Минимальная заработная плата 50 000 рублей максимальная заработная плата 24304876 рублей. Наибольшая часть заработных плат сосредоточена в диапазоне от 50000 до 200000 рублей. Для признака заработных плат присутствует аномалии, все что больше 700000 рублей можно считать за аномалию.

# %% [markdown]
# 4. Постройте диаграмму, которая показывает зависимость **медианной** желаемой заработной платы (**"ЗП (руб)"**) от уровня образования (**"Образование"**). Используйте для диаграммы данные о резюме, где желаемая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по представленной диаграмме: для каких уровней образования наблюдаются наибольшие и наименьшие уровни желаемой заработной платы? Как вы считаете, важен ли признак уровня образования при прогнозировании заработной платы?*

# %%
df_salary = df[df['Зарплата в рублях'] < 1000000].groupby('Образование')['Зарплата в рублях'].median().reset_index()

plt.figure(figsize=(16, 6))
sns.barplot(
    x='Образование', 
    y='Зарплата в рублях',
    hue='Образование',  
    data=df_salary, 
    palette='Set2')
plt.xlabel('Уровень образования')
plt.ylabel('Медианная желаемая ЗП')
plt.title('Зависимость медианной желаемой заработной платы от уровня образования')
plt.show()

# %% [markdown]
# Выводы
# * Самый высокий уровень желаемой зарплаты у соискателей с вышим образованием. Скорее всего это связано с тем, что претенденты в данной категории претендуют на более квалифицированные должности.
#
# * Кандидаты со средним и средним специальным образованием указывают в резюме более низкую заработную плату, это можно связать с более низким уровнем квалификации и соответственно менее квалифицированными позициями, на которые они претендуют. Также необходимо отметить, что разница медианной заработной платы для этих категорий минимальна.
#
# * Желаемая зарплата для неоконченного высшего образования находится между средним специальным и высшим образованием, что отражает промежуточный статус таких соискателей.

# %% [markdown]
# 5. Постройте диаграмму, которая показывает распределение желаемой заработной платы (**"ЗП (руб)"**) в зависимости от города (**"Город"**). Используйте для диаграммы данные о резюме, где желая заработная плата меньше 1 млн рублей.
# *Сделайте выводы по полученной диаграмме: как соотносятся медианные уровни желаемой заработной платы и их размах в городах? Как вы считаете, важен ли признак города при прогнозировании заработной платы?*

# %%
# Фильтрация данных
df_filtered = df[df['Зарплата в рублях'] < 1000000]
median_salaries = df_filtered.groupby('Город')['Зарплата в рублях'].median().reset_index()

# Сортируем города по убыванию медианной зарплаты
sorted_order = median_salaries.sort_values('Зарплата в рублях', ascending=False)['Город'].tolist()

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Построение boxplot
sns.boxplot(
    data=df_filtered, 
    x='Город', 
    y='Зарплата в рублях',
    hue='Город',
    palette='Set2',
    order=sorted_order,
    ax=axes[0])
axes[0].set_title('Распределение желаемой ЗП по городам')
axes[0].set_xlabel('Город')
axes[0].set_ylabel('Желаемая ЗП (руб)')
axes[0].tick_params(axis='x', rotation=45) 

# Построение barplot (медианные значения)
sns.barplot(
    data=median_salaries,
    x='Город', 
    y='Зарплата в рублях',
    hue='Город',
    palette='Set2',
    ax=axes[1])
axes[1].set_title('Медианная желаемая ЗП по городам')
axes[1].set_xlabel('Город')
axes[1].set_ylabel('Медианная ЗП (руб)')
axes[1].tick_params(axis='x', rotation=45)

# Отображение графиков
plt.tight_layout()
plt.show()

# %%
df[(df['Зарплата в рублях'] > 400000) & (df['Зарплата в рублях'] < 1000000) & (df['Город'] == 'другие')][['Город', 'Зарплата в рублях']]
# Out:
#         Город  Зарплата в рублях
# 11781  другие           700000.0
# 12890  другие           450000.0
# 23838  другие           459201.0
# 30193  другие           560141.4
# 33449  другие           923983.0
# 34953  другие           460000.0

# %% [markdown]
# Выводы
# * Уровень желаемой заработной платы в Москве и Санкт-Петербурге выше чем для других городов, это связано с более высокой стоимостью жизни в этих городах. При этом в Москве желаемая заработная плата самая высокая.
#
# * Желаемая заработная плата в городах-миллионниках ниже, чем в Москве и Санкт-Петербурге, однако превышает уровень, ожидаемый в категории "другие".
#
# * В категории другие присутствуют ряд резюме с высокими ожиданиями по заработной плате и высокими должностными позициями, данные резюме направлены на релокацию в другие города с более высокой медианной заработной платой.

# %% [markdown]
# 6. Постройте **многоуровневую столбчатую диаграмму**, которая показывает зависимость медианной заработной платы (**"ЗП (руб)"**) от признаков **"Готовность к переезду"** и **"Готовность к командировкам"**. Проанализируйте график, сравнив уровень заработной платы в категориях.

# %%
df_salary = df.groupby(['Готовность к переезду', 'Готовность к командировкам'])['Зарплата в рублях'].median().reset_index()

# %%
plt.figure(figsize=(16, 6))
sns.barplot(
    x='Готовность к переезду', 
    y='Зарплата в рублях', 
    hue='Готовность к командировкам', 
    data=df_salary,
    palette='Set2'
)
plt.ylabel('Зарплата в рублях')
plt.title('Зависимость медианной заработной платы\n от готовности к переезду и командировкам')
plt.legend(title='Готовность к\n командировкам', loc='upper right')
plt.show()

# %% [markdown]
# Чему равна желаемая медианная заработная плата соискателей, готовых и к переезду, и к командировкам? Ответ приведите в тысячах, округлив до целого

# %%
round(df[(df['Готовность к переезду'] == True) & (df['Готовность к командировкам'] == True)]['Зарплата в рублях'].median() / 1000, 0)
# Out:
# np.float64(66.0)

# %% [markdown]
# Выводы по графику
# * У соискателей готовых к переезду зарплатные ожидания выше чем у неготовых. Это коррелирует с графиком медианной заработной платы в зависимости от типа города (см. Зависимость медианной желаемой заработной платы от города).
# * Соискатели, готовые к командировкам, также имеют более высокую медианную зарплату по сравнению с теми, кто не готов к ним, скорее всего это обусловлено спецификой решаемых задач и дополнительными неудобствами связанными с подобным видом деятельности, возможно присутствует и обратная зависимость, когда рынок труда вакансий связанных с командировками предлагает более высокий уровень заработных плат (требуется исследование).

# %% [markdown]
# 7. Постройте сводную таблицу, иллюстрирующую зависимость **медианной** желаемой заработной платы от возраста (**"Возраст"**) и образования (**"Образование"**). На полученной сводной таблице постройте **тепловую карту**. Проанализируйте тепловую карту, сравнив показатели внутри групп.

# %%
pivot = df.pivot_table(
    index='Образование',
    columns='Возраст',
    values='Зарплата в рублях',
    aggfunc='median',
    fill_value=0
)

# Создание тепловой карты с seaborn
plt.figure(figsize=(16, 6))  # Размер графика
sns.heatmap(
    pivot, 
    fmt=".1f", 
    cmap='Oranges',  
    linewidths=0.5,
    # yticklabels = False,  
    cbar_kws={'label': 'Медианная з/п (руб)'} 
)

# Настройка заголовка и меток
plt.title('Медианная в зависимости от образования и возраста', fontsize=12)
plt.xlabel('Возраст', fontsize=12)
plt.ylabel('Образование', fontsize=12)
plt.yticks(rotation=45)

# Отображение графика
plt.show()

# %% [markdown]
# Выводы по графику
# * Для категорий "среднее специальное" и "среднее" образование медианная заработная плата с увеличением возраста снижается.
# * Для категорий "высшее" и "неоконченное высшее" образование  присутствует тенденция роста заработной платы с возрастом при это для категории высшее образование эта тенденция является ярко выраженной.

# %% [markdown]
# 8. Постройте **диаграмму рассеяния**, показывающую зависимость опыта работы (**"Опыт работы (месяц)"**) от возраста (**"Возраст"**). Опыт работы переведите из месяцев в года, чтобы признаки были в едином масштабе. Постройте на графике дополнительно прямую, проходящую через точки (0, 0) и (100, 100). Данная прямая соответствует значениям, когда опыт работы равен возрасту человека. Точки, лежащие на этой прямой и выше нее - аномалии в наших данных (опыт работы больше либо равен возрасту соискателя)

# %%
# scatter_df = df[(df['Опыт работы (месяц)'] < 600) & (df['Возраст'] < 70) ]
scatter_df = df
fig = plt.figure(figsize=(16, 6))

# Построение линии ориентира
# sns.lineplot(x=[14, 70], y=[0, (70-14)*12])
sns.lineplot(x=[0, 100], y=[0, 1200])


# Построение точечного графика
ax = sns.scatterplot(
    data=scatter_df,
    color='blue',
    x='Возраст',
    y='Опыт работы (месяц)',
    alpha=0.08
)

# Заголовок графика
ax.set_title('Зависимость опыта работы от возраста')
# Out:
# Text(0.5, 1.0, 'Зависимость опыта работы от возраста')

# %% [markdown]
# Сколько точек лежат строго выше построенной прямой? Так как точки могут сливаться с прямой, то для ответа на этот вопрос проще всего воспользоваться интерактивной визуализацией либо получить таблицу с наблюдениями, лежащими выше прямой с помощью фильтрации.

# %%
# Вывод количества резюме, в которых опыт работы больше или равен теоретически возможному стажу на момент текущий момент времени
# scatter_df[(scatter_df['Опыт работы (месяц)']) > scatter_df['Возраст'] * 12 - 14 *12].shape[0]
scatter_df[scatter_df['Опыт работы (месяц)'] >= scatter_df['Возраст'] * 12].shape[0]
# Out:
# 7

# %% [markdown]
# Выводы
#
# * На диаграмме рассеивания видно, что опыт растет вместо с возрастом. Распределение опыта работы находится ниже ориентира для сравнения. Но также присутствую вакансии у которых опыт превышает этот ориентир.
# * В целом независимо от возраста встречаются резюме с различным опытом работы. Падает только количество самих резюме. Но все же присутствует тенденция сокращения количества резюме со средним опытом работы после 60 лет. Возможно рынком в этом возрасте востребованы либо кадры с высокой квалификацией либо с низкой.

# %% [markdown]
# **Дополнительные баллы**
#
# Для получения 2 дополнительных баллов по разведывательному анализу постройте еще два любых содержательных графика или диаграммы, которые помогут проиллюстрировать влияние признаков/взаимосвязь между признаками/распределения признаков. Приведите выводы по ним. Желательно, чтобы в анализе участвовали признаки, которые мы создавали ранее в разделе "Преобразование данных".

# %% [markdown]
# ### Зависимость зарплаты от возраста
# Цель: Показать, как зарплата зависит от возраста c

# %%
scatter_df = df[(df['Зарплата в рублях'] < 1000000) & (df['Возраст'] < 70) ]
fig = plt.figure(figsize=(16, 6))

# Построение линии ориентира
# sns.lineplot(x=[14, 70], y=[0, (70-14)*12])

# Построение точечного графика
ax = sns.scatterplot(
    data=scatter_df,
    color='orange',
    x='Возраст',
    y='Зарплата в рублях',
    alpha=0.2
)

# Заголовок графика
ax.set_title('Зависимость уровня заработной платы от возраста')
# Out:
# Text(0.5, 1.0, 'Зависимость уровня заработной платы от возраста')

# %% [markdown]
# Выводы
#
# * На графике видна тенденция роста запрашиваемой заработной платы от 28 лет до 48 лет, далее уровень запрашиваемой заработной платы снижается, скорее всего это связано с наибольше активностью в этом возрастном диапазоне.
# * Максимальная зарплата наблюдается в возрасте около 40-50 лет.
# * В возрасте 20-30 лет наблюдается большой разброс зарплат, что может быть связано с различиями в профессиях, опыте или уровне образования.
# * После 50 лет разброс уменьшается, что может указывать на более однородные зарплатные ожидания.

# %% [markdown]
# ### Отображения распределения опыта работы по городам

# %%
boxplot_df = df[df['Опыт работы (месяц)'] < 800]
# Создание boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(
    x='Город', 
    y='Опыт работы (месяц)',
    hue='Город', 
    data=boxplot_df, 
    palette="Set2")

# Добавление заголовка и подписей
plt.title('Распределение опыта работы по городам', fontsize=16)
plt.xlabel('Город', fontsize=14)
plt.ylabel('Опыт работы (месяц)', fontsize=14)

# Отображение графика
plt.show()

# %% [markdown]
# Выводы
#
# * Опыт работы в Москве имеет самый широкий разброс, что может указывать на большое разнообразие соискателей с разным уровнем опыта.
# * Во всех городах медиана находится на приблизительно на среднем уровне, что говорит о том, что большинство соискателей имеют умеренный опыт работы вне зависимости от типа города.
# * В категории "Другие" опыт работы имеет самый низкий уровень, а разброс минимален, что может указывать на то, что в небольших городах соискатели имеют меньше возможностей для накопления опыта.

# %% [markdown]
# # Очистка данных

# %% [markdown]
# 1. Начнем с дубликатов в наших данных. Найдите **полные дубликаты** в таблице с резюме и удалите их.

# %%
duplicates = df[df.duplicated()]
df = df.drop_duplicates()
duplicates.shape[0]
# Out:
# 159

# %% [markdown]
# 2. Займемся пропусками. Выведите информацию **о числе пропусков** в столбцах.

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# Ищет работу на должность:            0
# Занятость                            0
# График                               0
# Последнее/нынешнее место работы      1
# Последняя/нынешняя должность         2
# Образование и ВУЗ                    0
# Обновление резюме                    0
# Авто                                 0
# Образование                          0
# Пол                                  0
# Возраст                              0
# Опыт работы (месяц)                168
# Город                                0
# Готовность к переезду                0
# Готовность к командировкам           0
# Полная занятость                     0
# Частичная занятость                  0
# Проектная работа                     0
# Стажировка                           0
# Волонтерство                         0
# Полный день                          0
# Сменный график                       0
# Гибкий график                        0
# Удалённая работа                     0
# ...

# %% [markdown]
# 3. Итак, у нас есть пропуски в 3ех столбцах: **"Опыт работы (месяц)"**, **"Последнее/нынешнее место работы"**, **"Последняя/нынешняя должность"**. Поступим следующим образом: удалите строки, где есть пропуск в столбцах с местом работы и должностью. Пропуски в столбце с опытом работы заполните **медианным** значением.

# %%
# Удаление строк с пропусками в столбцах "Последнее/нынешнее место работы" и "Последняя/нынешняя должность"
df_cleaned = df.copy()
df_cleaned = df_cleaned.dropna(subset=['Последнее/нынешнее место работы', 'Последняя/нынешняя должность'])

# Заполнение пропусков в столбце "Опыт работы (месяц)" медианным значением
median_exp = df_cleaned['Опыт работы (месяц)'].median()
df_cleaned['Опыт работы (месяц)'] = df_cleaned['Опыт работы (месяц)'].fillna(median_exp)

# %% [markdown]
# Чему равно результирующее среднее значение в столбце «Опыт работы (месяц)» после заполнения пропусков? Ответ округлите до целых.

# %% [markdown]
# 4. Мы добрались до ликвидации выбросов. Сначала очистим данные вручную. Удалите резюме, в которых указана заработная плата либо выше 1 млн. рублей, либо ниже 1 тыс. рублей.

# %%
display(df_cleaned[(df_cleaned['Зарплата в рублях'] > 1e6) | (df_cleaned['Зарплата в рублях'] < 1e3)].shape[0])
df_cleaned['Зарплата в рублях'] = df_cleaned[(df_cleaned['Зарплата в рублях'] > 1e6) | (df_cleaned['Зарплата в рублях'] < 1e3)].shape[0]
# Out:
# 89

# %% [markdown]
# 5. В процессе разведывательного анализа мы обнаружили резюме, в которых **опыт работы в годах превышал возраст соискателя**. Найдите такие резюме и удалите их из данных

# %%
df_cleaned[df_cleaned['Опыт работы (месяц)'] >= df_cleaned['Возраст'] * 12].shape[0]
# Out:
# 7

# %% [markdown]
# 6. В результате анализа мы обнаружили потенциальные выбросы в признаке **"Возраст"**. Это оказались резюме людей чересчур преклонного возраста для поиска работы. Попробуйте построить распределение признака в **логарифмическом масштабе**. Добавьте к графику линии, отображающие **среднее и границы интервала метода трех сигм**. Напомним, сделать это можно с помощью метода axvline. Например, для построение линии среднего будет иметь вид:
#
# `histplot.axvline(log_age.mean(), color='k', lw=2)`
#
# В какую сторону асимметрично логарифмическое распределение? Напишите об этом в комментарии к графику.
# Найдите выбросы с помощью метода z-отклонения и удалите их из данных, используйте логарифмический масштаб. Давайте сделаем послабление на **1 сигму** (возьмите 4 сигмы) в **правую сторону**.
#
# Выведите таблицу с полученными выбросами и оцените, с каким возрастом соискатели попадают под категорию выбросов?

# %%
fig, ax = plt.subplots(1, 1, figsize=(16, 8))
df_cleaned['Логарифм возраста'] = np.log(df_cleaned['Возраст'])
histplot = sns.histplot(df_cleaned['Логарифм возраста'], bins=25, ax=ax)
histplot.axvline(
    df_cleaned['Логарифм возраста'].mean(), 
    color='blue', 
    lw=2)
histplot.axvline(df_cleaned['Логарифм возраста'].mean() + 4 * df_cleaned['Логарифм возраста'].std(), color='red', ls='--', lw=2)
histplot.axvline(df_cleaned['Логарифм возраста'].mean() - 3 * df_cleaned['Логарифм возраста'].std(), color='red', ls='--', lw=2)  
histplot.set_title('Логарифмическое распределение возраста')
# Out:
# Text(0.5, 1.0, 'Логарифмическое распределение возраста')

# %%
# Вычисление z-отклонений
mean_log_age = df_cleaned['Логарифм возраста'].mean()
std_log_age = df_cleaned['Логарифм возраста'].std()
df_cleaned['z_score'] = (df_cleaned['Логарифм возраста'] - mean_log_age) / std_log_age

# Определение выбросов (4 сигмы в правую сторону)
df_cleaned[(df_cleaned['z_score'] > 4) | (df_cleaned['z_score'] < -3)][['Возраст', 'Ищет работу на должность:', 'Логарифм возраста', 'z_score']]
# Out:
#        Возраст       Ищет работу на должность:  Логарифм возраста   z_score
# 29098       14     Ведущий инженер-программист           2.639057 -3.483863
# 31137       15  Менеджер по работе с клиентами           2.708050 -3.185332
# 32950       15                 Тестировщик игр           2.708050 -3.185332
# 33654      100            Frontend-разработчик           4.605170  5.023466
